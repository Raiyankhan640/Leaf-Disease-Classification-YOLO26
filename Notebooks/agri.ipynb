# %%
import torch
print(torch.cuda.get_device_name(0))
# Out:
# NVIDIA GeForce RTX 4060 Ti

# %%
from ultralytics import YOLO

model = YOLO("yolo26n-cls.pt")
results = model.train(
    data=r"C:/Users/KRYPT/Downloads/AgriVision/",
    epochs=100,
    imgsz=512,
    batch=16,
    device=0,
    project="runs/local_train",
    name="57cls_first",
    patience=25,
    optimizer="AdamW",
    lr0=0.01,
    cos_lr=True,
    augment=True,
    save_period=10
)
model.val()
model.export(format="onnx")
# Out:
# New https://pypi.org/project/ultralytics/8.4.18 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.17  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 16380MiB)
# ...
